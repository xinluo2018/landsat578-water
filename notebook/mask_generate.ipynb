# %%
# ## Mount on google drive
# from google.colab import drive
# drive.mount('/content/drive/')

# %%
import config
import os
os.chdir(config.root)
import matplotlib.pyplot as plt
from utils.mask_by_shp import mask_by_shp
from utils.tiff_io import readTiff
from utils.imgShow import imgShow

# %%
scene_name = 'l8_scene_07'
path_shp = 'data/dataset-l578/gpkg/'+scene_name+'_truth_final.gpkg'
path_raster = 'data/dataset-l578/scene/'+ scene_name+'.tif'
path_output = 'data/dataset-l578/truth/'+ scene_name + '_truth.tif'

img_src, img =readTiff(path_in=path_raster)
mask = mask_by_shp(path_raster=path_raster, path_shp=path_shp, path_output=path_output)
mask.shape
# Out:
# (1328, 1456)

# %%
plt.figure(figsize=(10,5))
plt.subplot(1,2,1)
imgShow(img)
plt.subplot(1,2,2)
imgShow(mask)
